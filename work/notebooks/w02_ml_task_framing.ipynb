# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rakshachahar/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# The selected lane is **Refresh / Content Opportunity Scoring**, which is best framed as a **classification** task. The objective is to classify website pages into those that should be prioritized for content review and those that do not currently require review. This supports content teams by helping them focus their efforts on pages with the greatest opportunity for improvement.

# %%
ml_task = "Classification"
print("Machine Learning Task:", ml_task)
# Out:
# Machine Learning Task: Classification

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target represents whether a website page should be prioritized for content refresh. Since direct future outcomes are not immediately observable, the label is defined using historical search-performance signals as a proxy. The label is based on observed performance rather than future search rankings.

# %%
target = "Content Refresh Priority"
label_source = "Observed historical search-performance signals"

print("Target:", target)
print("Label Source:", label_source)
# Out:
# Target: Content Refresh Priority
# Label Source: Observed historical search-performance signals

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The primary evaluation metric is **Accuracy** together with comparison against the baseline model. A higher accuracy than the rule-based baseline indicates that the model provides improved decision-support while maintaining fair evaluation on the same validation split.

# %%
metric = "Accuracy"
goal = "Higher than baseline"

print("Evaluation Metric:", metric)
print("Success Goal:", goal)
# Out:
# Evaluation Metric: Accuracy
# Success Goal: Higher than baseline

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is a single website content page. Each row in the dataset represents one page together with its observable search-performance features such as impressions, clicks, average search position, and click-through rate.

# %%
import pandas as pd

df = pd.DataFrame({
    "Unit of Analysis": ["Website Content Page"],
    "Features": ["Impressions, Clicks, CTR, Avg Position"]
})

df
# Out:
#        Unit of Analysis                                Features
# 0  Website Content Page  Impressions, Clicks, CTR, Avg Position

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule may rely on only one or two search-performance metrics, such as impressions or click-through rate. Machine learning can evaluate multiple observable signals simultaneously and identify more complex relationships between them, producing more reliable prioritization for content review while remaining decision-support rather than fully automated decision-making.

# %%
reason = (
    "Machine learning combines multiple search-performance signals "
    "instead of relying on a single fixed rule."
)

print(reason)
# Out:
# Machine learning combines multiple search-performance signals instead of relying on a single fixed rule.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
