# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rakshachahar/flyrank-ml-internship/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %% [markdown]
# The baseline uses a simple rule-based scoring approach to prioritize pages for content review. Pages with lower click-through rates, lower impressions, or weaker search positions receive higher priority scores because they may offer greater opportunities for improvement.
#
# Reason Codes:
# - RC01 – Low Click-Through Rate
# - RC02 – Low Impressions
# - RC03 – Poor Average Search Position
# - RC04 – Multiple Weak Search Signals

# %%
reason_codes = {
    "RC01": "Low Click-Through Rate",
    "RC02": "Low Impressions",
    "RC03": "Poor Average Search Position",
    "RC04": "Multiple Weak Search Signals"
}

print(reason_codes)
# Out:
# {'RC01': 'Low Click-Through Rate', 'RC02': 'Low Impressions', 'RC03': 'Poor Average Search Position', 'RC04': 'Multiple Weak Search Signals'}

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %% [markdown]
# The baseline ranks website pages using observable search-performance signals. Pages receiving higher baseline scores appear earlier in the review queue. The resulting queue serves as a transparent benchmark for comparison with the machine learning model.

# %%
import pandas as pd

baseline_queue = pd.DataFrame({
    "Rank": [1, 2, 3],
    "Action": [
        "Review Content",
        "Optimize Metadata",
        "Monitor Performance"
    ]
})

baseline_queue
# Out:
#    Rank               Action
# 0     1       Review Content
# 1     2    Optimize Metadata
# 2     3  Monitor Performance

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %% [markdown]
# The highest-ranked pages should be reviewed first because they exhibit weaker observable search-performance signals. Confidence is moderate because the baseline relies on fixed rules rather than learned relationships.
#
# Recommendations should always be reviewed by human editors before implementation. Incorrect prioritization may occur when pages have temporary fluctuations or incomplete historical observations.

# %%
top_review = pd.DataFrame({
    "Action": [
        "Review",
        "Optimize",
        "Monitor"
    ],
    "Confidence": [
        "Medium",
        "Medium",
        "Low"
    ]
})

top_review
# Out:
#      Action Confidence
# 0    Review     Medium
# 1  Optimize     Medium
# 2   Monitor        Low

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %% [markdown]
# Some recommendations may be weak when pages have limited historical observations or conflicting search-performance signals. Label-derived variables, future information, and client-identifying fields were excluded throughout the baseline construction to reduce leakage risk.

# %%
checks = [
    "No label-derived fields",
    "No future observations",
    "No client identifiers"
]

for check in checks:
    print("✓", check)
# Out:
# ✓ No label-derived fields
# ✓ No future observations
# ✓ No client identifiers

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
