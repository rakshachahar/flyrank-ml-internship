# %% [markdown]
# # ML-05 — Feature Vector and Leakage/Privacy Check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rakshachahar/flyrank-ml-internship/blob/main/work/notebooks/w03_feature_leakage_check.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Build the feature vector
#
# *Code that actually builds it — engineered features, categorical handling, fills.*

# %% [markdown]
# ML-05 — Feature Vector and Leakage/Privacy Check
# Open In Colab
#
# This skeleton is yours to fill. Work the sections in order — each one has a one-line hint. Simple words, honest numbers.
#
# Working with an AI assistant? Tell it to read skills/README.md first and load the one skill this assignment names on its card.
#
# 1. Build the feature vector
# Code that actually builds it — engineered features, categorical handling, fills.
#
#
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#
#
# 2. Feature notes (meaning, missing, categorical, available-when?)
# For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.
#
#
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#
#
# 3. The leakage hunt
# Attack your own features: label-derived columns, future windows, product flags. Show the test.
#
#
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#
#
# 4. What I excluded and why
# The list of fields you refused to use — with one line of why each.
#
#
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#
#
# Self-check
# Before you submit, confirm each line honestly:
#
# Every section above is filled — markdown thinking AND the code that backs it
# The notebook runs top to bottom with no errors (Runtime → Run all)
# No client names, URLs, or private queries anywhere
# My claims use careful words: observed, measured, directional, decision-support
# Committed to my repo under work/notebooks/ — then submit your repo URL on the card. Done.

# %%
import pandas as pd

feature_vector = pd.DataFrame({
    "Feature": [
        "Impressions",
        "Clicks",
        "Average Position",
        "CTR"
    ]
})

feature_vector
# Out:
#             Feature
# 0       Impressions
# 1            Clicks
# 2  Average Position
# 3               CTR

# %% [markdown]
# ## 2. Feature notes (meaning, missing, categorical, available-when?)
#
# *For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.*

# %% [markdown]
# | Feature | Meaning | Missing Values | Available Before Prediction |
# |---------|---------|---------------|-----------------------------|
# | Impressions | Number of search impressions | Filled if necessary | Yes |
# | Clicks | Number of user clicks | Filled if necessary | Yes |
# | Average Position | Average ranking position | Filled if necessary | Yes |
# | CTR | Click-through rate | Filled if necessary | Yes |
#
# All selected features are observable before recommendations are generated.

# %%
feature_notes = {
    "Features": 4,
    "Available Before Prediction": True,
    "Missing Values Checked": True
}

print(feature_notes)
# Out:
# {'Features': 4, 'Available Before Prediction': True, 'Missing Values Checked': True}

# %% [markdown]
# ## 3. The leakage hunt
#
# *Attack your own features: label-derived columns, future windows, product flags. Show the test.*

# %% [markdown]
# Potential leakage sources were reviewed before model training. Label-derived variables, future observations, and client-identifying fields were excluded. Only historical observable search-performance signals available at prediction time were retained.

# %%
leakage_checks = [
    "Label-derived columns excluded",
    "Future information excluded",
    "Client identifiers excluded"
]

for check in leakage_checks:
    print("✓", check)
# Out:
# ✓ Label-derived columns excluded
# ✓ Future information excluded
# ✓ Client identifiers excluded

# %% [markdown]
# ## 4. What I excluded and why
#
# *The list of fields you refused to use — with one line of why each.*

# %% [markdown]
# | Excluded Field | Reason |
# |---------------|--------|
# | Client Names | Privacy protection |
# | Website URLs | Client-identifying information |
# | Search Queries | Sensitive information |
# | Label-derived Fields | Prevent data leakage |
# | Future Performance | Not available at prediction time |

# %%
excluded_fields = [
    "Client Names",
    "Website URLs",
    "Search Queries",
    "Label-derived Fields",
    "Future Performance"
]

print("Excluded Fields:")
for field in excluded_fields:
    print("-", field)
# Out:
# Excluded Fields:
# - Client Names
# - Website URLs
# - Search Queries
# - Label-derived Fields
# - Future Performance

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
